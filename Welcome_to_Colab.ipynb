# %% [markdown]
# <a href="https://colab.research.google.com/github/Tawhida222/C-programming/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load data
df = pd.read_csv("heart_failure_prediction.csv")

# Count of null values BEFORE handling
print("🔍 Null values before replacement:\n")
print(df.isnull().sum())

# Total missing values
total_missing_before = df.isnull().sum().sum()
print(f"\n👉 Total missing values before replacement: {total_missing_before}\n")

# Replace nulls
for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:
        df[column].fillna(df[column].mean(), inplace=True)
    else:
        df[column].fillna(df[column].mode()[0], inplace=True)

# Count of null values AFTER handling
print("✅ Null values after replacement:\n")
print(df.isnull().sum())

# Total missing values
total_missing_after = df.isnull().sum().sum()
print(f"\n✅ Total missing values after replacement: {total_missing_after}")
# Out:
# 🔍 Null values before replacement:
#
# Age                           0
# Gender                        0
# Chest_Pain_Type               0
# Resting_BP                    0
# Cholesterol                   0
# Fasting_Blood_Sugar           0
# Resting_ECG                   0
# Max_Heart_Rate                0
# Exercise_Induced_Angina       0
# Oldpeak                       0
# Slope                         0
# Num_Major_Vessels             0
# Thalassemia                   0
# Diabetes                      0
# Smoking_History               0
# Alcohol_Consumption        3350
# Physical_Activity_Level       0
# Family_History                0
# BMI                           0
# Heart_Failure                 0
# dtype: int64
#
# 👉 Total missing values before replacement: 3350
#
# ✅ Null values after replacement:
#
# Age                        0
# Gender                     0
# Chest_Pain_Type            0
# Resting_BP                 0
# Cholesterol                0
# ...

# %%
import pandas as pd

# Load data
df = pd.read_csv("heart_failure_prediction.csv")

# Count of null values BEFORE handling
print("🔍 Null values before replacement:\n")
print(df.isnull().sum())

# Total missing values
total_missing_before = df.isnull().sum().sum()
print(f"\n👉 Total missing values before replacement: {total_missing_before}\n")

# Replace nulls
for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:
        df[column].fillna(df[column].mean(), inplace=True)
    else:
        df[column].fillna(df[column].mode()[0], inplace=True)

# Count of null values AFTER handling
print("✅ Null values after replacement:\n")
print(df.isnull().sum())

# Total missing values
total_missing_after = df.isnull().sum().sum()
print(f"\n✅ Total missing values after replacement: {total_missing_after}")
# Out:
# 🔍 Null values before replacement:
#
# Age                           0
# Gender                        0
# Chest_Pain_Type               0
# Resting_BP                    0
# Cholesterol                   0
# Fasting_Blood_Sugar           0
# Resting_ECG                   0
# Max_Heart_Rate                0
# Exercise_Induced_Angina       0
# Oldpeak                       0
# Slope                         0
# Num_Major_Vessels             0
# Thalassemia                   0
# Diabetes                      0
# Smoking_History               0
# Alcohol_Consumption        3350
# Physical_Activity_Level       0
# Family_History                0
# BMI                           0
# Heart_Failure                 0
# dtype: int64
#
# 👉 Total missing values before replacement: 3350
#
# ✅ Null values after replacement:
#
# Age                        0
# Gender                     0
# Chest_Pain_Type            0
# Resting_BP                 0
# Cholesterol                0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of numeric features
numeric_cols = ["Age", "Resting_BP", "Cholesterol", "Max_Heart_Rate", "Oldpeak", "BMI"]

# Plot boxplots
plt.figure(figsize=(16, 10))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(data=df, y=col, color="lightcoral")
    plt.title(f'Boxplot of {col}')
    plt.ylabel(col)

plt.tight_layout()
plt.suptitle("Boxplots for Outlier Detection", fontsize=16, y=1.02)
plt.show()

# %%
# Example: Identify outliers in 'Cholesterol'
Q1 = df['Cholesterol'].quantile(0.25)
Q3 = df['Cholesterol'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['Cholesterol'] < Q1 - 1.5 * IQR) | (df['Cholesterol'] > Q3 + 1.5 * IQR)]
print(f"Number of outliers in 'Cholesterol': {outliers.shape[0]}")
# Out:
# Number of outliers in 'Cholesterol': 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Check distribution of Heart Failure classes
print(df['Heart_Failure'].value_counts())
print("\nClass distribution (in %):")
print(df['Heart_Failure'].value_counts(normalize=True) * 100)

# Plot class distribution
sns.countplot(data=df, x='Heart_Failure', palette='Set2')
plt.title("Class Distribution: Heart Failure")
plt.xlabel("Heart Failure (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()
# Out:
# Heart_Failure
# 1    5036
# 0    4964
# Name: count, dtype: int64
#
# Class distribution (in %):
# Heart_Failure
# 1    50.36
# 0    49.64
# Name: proportion, dtype: float64
# <ipython-input-6-5972cd272642>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Heart_Failure', palette='Set2')
